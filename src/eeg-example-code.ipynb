# %%
#default_path setting
import os
default_path = '/home/devmin/Desktop/source/jupyter/research-EEG'
print(default_path)
print(os.chdir(default_path))
del default_path
from scipy import io
import numpy as np
data = io.loadmat('./data/sub_1Day2_200508')
# Out:
# /home/devmin/Desktop/source/jupyter/research-EEG
# None

# %%
# print(data)
FeatVect = data['rawData']
print(FeatVect)
print(FeatVect.shape)
    # # 3-dimentiona array = [trials x channels x time-series]
    # Timesegment = 10
    # Fs = 200
    # FeatVect = FeatVect[:, :, 0:(Timesegment*Fs)]
    # y_labels = raw_labels['y_label']
    # del raw_data, raw_labels
# Out:
# [[[ 1.1323585  -1.34459244 -3.35396717 ... -9.98291384 -3.24969446
#     3.96364428]
#   [-0.43077746 -0.75344359 -1.88929276 ... -0.28369472 -1.24731628
#    -2.23314383]
#   [-0.67655038 -0.82073889 -1.62075165 ...  1.36551895  0.08994823
#    -1.47219679]
#   [ 1.06832968  2.4712856   3.61978651 ...  4.55534013  1.87359762
#     0.64478924]
#   [-0.29118583  0.10301865  0.4893351  ...  3.80196094  0.89807935
#    -0.07532478]
#   [ 0.28997377 -0.533512   -1.27807475 ...  3.52290178 -0.09121618
#    -0.51721464]]
#
#  [[ 2.99346015  1.11542489 -0.45170955 ... -1.23169056 -2.4688804
#    -1.31983825]
#   [-0.77107742  0.07202396  0.59888254 ... -0.61365854 -0.37206131
#    -2.33465519]
#   [-0.95849143  0.44730108  1.90429538 ... -0.65862322 -0.81442467
#    -2.28333649]
#   [-0.1630998   0.3469694   2.2261852  ...  1.56680355  2.58119028
#     4.46018015]
#   [-1.11358314  1.07680411  4.29176842 ...  0.96069205  2.38253539
#     3.92057617]
# ...
